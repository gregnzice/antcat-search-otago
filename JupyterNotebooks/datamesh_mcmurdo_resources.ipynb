# %%
import json

# %%
#Define your datamesh token in evironment variables as DATAMESH_TOKEN or insert into argument below.
from oceanum.datamesh import Connector
datamesh=Connector(token="6c9de54090ad838542a8df0b04db4d1f28138e31")
# Out:
# You are using version 1.0.16 of oceanum_python. A new version is available: 1.0.17. Please update your client to benefit from the latest features and updates.
# Using datamesh API version 1

# %%
#Query request for datasource oceanographic_mooring_mcmurdo_sound_jt_2014_2015
oceanographic_mooring_mcmurdo_sound_jt_2014_2015_query={"datasource":"oceanographic_mooring_mcmurdo_sound_jt_2014_2015","parameters":{},"description":"Oceanographic Mooring, McMurdo Sound (JT), 2014-2015","variables":["date_time","depth","temperature","pressure"],"functions":[],"id":"08546c0209922292eb02c26a1d089371"}
oceanographic_mooring_mcmurdo_sound_jt_2014_2015=datamesh.query(oceanographic_mooring_mcmurdo_sound_jt_2014_2015_query)
dsrc = datamesh.get_datasource("oceanographic_mooring_mcmurdo_sound_jt_2014_2015")

# %% [markdown]
# ## Show the metadata for the resource

# %%
print(json.dumps(dsrc.attributes, indent=2))
# Out:
# {
#   "doi": "https://www.usap-dc.org/view/dataset/601141",
#   "title": "Oceanographic Mooring, McMurdo Sound (JT), 2014-2015",
#   "source": "Mooring instruments including CTD",
#   "Contact": "Shenjie Zhou, shezhou@bas.ac.uk",
#   "License": "Creative Commons Attribution-NonCommercial v4.0 Generic [CC BY-NC 4.0]",
#   "comment": "Data collected as part of ongoing monitoring in the Ross Sea region.",
#   "history": "Data processed and quality controlled by BODC",
#   "summary": "This dataset consists of measurements made of temperature, pressure at JT site in McMurdo Sound. Sensors logged every 4 hours and ran until batteries were exhausted. Sensors were calibrated with water samples following best practices from Dickson et al (2007). Details of select years from this dataset are provided in Kapsenberg et al(2015).\"",
#   "keywords": "ASP, MOORINGS, MCMURDO SOUND, CTD, OCEANOGRAPHY, OCEAN PRESSURE, OCEAN TEMPERATURE, ANTARCTICA",
#   "Repository": "USAP-DC (current)",
# ...

# %% [markdown]
# ## Inspect the data

# %%
print(oceanographic_mooring_mcmurdo_sound_jt_2014_2015)
# Out:
# <xarray.Dataset> Size: 71kB
# Dimensions:       (instrument: 1, observations: 1967, mooring_site: 1)
# Coordinates:
#   * instrument    (instrument) int32 4B 1
#     latitude      float64 8B -77.85
#     longitude     float64 8B 166.7
#   * mooring_site  (mooring_site) <U2 8B 'JT'
#   * observations  (observations) int32 8kB 0 1 2 3 4 ... 1963 1964 1965 1966
# Data variables:
#     date_time     (instrument, observations, mooring_site) datetime64[ns] 16kB ...
#     depth         (instrument, observations, mooring_site) float64 16kB 15.0 ...
#     pressure      (instrument, observations, mooring_site) float64 16kB 15.16...
#     temperature   (instrument, observations, mooring_site) float64 16kB -1.33...
# Attributes: (12/27)
#     Contact:                  Shenjie Zhou, shezhou@bas.ac.uk
#     Conventions:              CF-1.7
#     Creation Date:            2018-12-05
#     Description:              OCEAN:ICE D1.1 - Pan-Antarctic (90S-60S) moored...
# ...

# %%
#Query request for datasource ctd_data_ocean_ice_antarctic_ice_shelf_asp
ctd_data_ocean_ice_antarctic_ice_shelf_asp_query={"datasource":"ctd_data_ocean_ice_antarctic_ice_shelf_asp","parameters":{},"description":"CTD Profiles, McMurdo Sound, 2015","variables":["conductivity","density","potential_temperature","pressure","salinity","temperature"],"functions":[],"id":"532eed7e73360c068737746cf04cc9cd"}
ctd_data_ocean_ice_antarctic_ice_shelf_asp=datamesh.query(ctd_data_ocean_ice_antarctic_ice_shelf_asp_query)
dsrc = datamesh.get_datasource("ctd_data_ocean_ice_antarctic_ice_shelf_asp")

# %% [markdown]
# ## Show the metadata

# %%
print(json.dumps(dsrc.attributes, indent=2))
# Out:
# {
#   "url": "https://www.seanoe.org/data/00792/90432/",
#   "title": "CTD and Microstructure Profiler Ocean-ice data from an Antarctic ice shelf water plume flowing beneath land-fast sea ice",
#   "summary": "Vertical profiles of temperature and salinity recorded using a SBE19+ CTD profiler and turbulent mixing measured using a Rockland VMP 250 microstructure profiler. Data includes high-resolution measurements of temperature, salinity, and velocity shear.",
#   "location": "Beneath Antarctic fast ice",
#   "conventions": "CF-1.8",
#   "methodology": "CTD profiler was calibrated pre- and post-experiment to ensure accuracy. Care was taken to avoid ice growth on the sensors and to thermally equilibrate before profiling. The microstructure profiler was loose-tethered and provided energy dissipation estimates.",
#   "instrument_1": "SBE19+ CTD Profiler",
#   "instrument_2": "Rockland VMP 250 Microstructure Profiler",
#   "experiment_period": "1-3 November 2015",
# ...

# %% [markdown]
# ## Print the data

# %%
print(ctd_data_ocean_ice_antarctic_ice_shelf_asp)
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:                (scan_count: 19941)
# Coordinates:
#   * scan_count             (scan_count) int64 160kB 1 2 3 ... 19939 19940 19941
# Data variables:
#     conductivity           (scan_count) float64 160kB -0.000169 ... 1.342
#     density                (scan_count) float64 160kB -0.0324 -0.0324 ... 0.8214
#     potential_temperature  (scan_count) float64 160kB 4.946 4.946 ... -1.898
#     pressure               (scan_count) float64 160kB -0.304 -0.304 ... -0.301
#     salinity               (scan_count) float64 160kB 0.0 0.0 ... 1.456 1.381
#     temperature            (scan_count) float64 160kB 4.946 4.946 ... -1.898
# Attributes: (12/17)
#     _coordinates:               {}
#     _datamesh_cache_hash:       8a7ef5804106745d4634ae8ba7e7214ea0d99e9654930...
#     _domain_size:               19941
#     _flattened_domain_size:     19941
#     _request_size:              1116696
#     conventions:                CF-1.8
# ...

# %%
#Query request for datasource adcp_sbr_site1_2019
adcp_sbr_site1_2019_query={"datasource":"adcp_sbr_site1_2019","parameters":{},"description":"ADCP Measurements (Temperature, Currents), Scott Base Redevelopment Marine Monitoring Site 1, 2019","variables":["amplitude_average","beam1_amplitude","beam1_correlation","beam2_amplitude","beam3_amplitude","beam3_correlation","correlation_average","depth","depth_bin","depth_floor","direction","heading_true","instrument_depth","latitude","longitude","magnetic_offset","magnitude","pitch","roll","temperature_of_seawater","tilt","time","u","uplooking","v","w","w2"],"functions":[],"id":"5297183db771ab599450ecbe0b9c7e47"}
adcp_sbr_site1_2019=datamesh.query(adcp_sbr_site1_2019_query)
dsrc = datamesh.get_datasource("adcp_sbr_site1_2019")

# %% [markdown]
# ## Show the metadata - missing attributes...

# %%
dsrc
# Out:
#         ADCP Measurements (Temperature, Currents), Scott Base Redevelopment Marine Monitoring Site 1, 2019 [adcp_sbr_site1_2019]
#             Extent: (166.7163160634297, -77.8598161565814, 166.80168393657027, -77.84184984341859)
#             Timerange: 2019-10-29 00:00:00+00:00 to 2019-11-20 00:00:00+00:00
#             0 attributes
#             27 variables

# %%
print(adcp_sbr_site1_2019)
# Out:
# <xarray.Dataset> Size: 20MB
# Dimensions:                  (index: 67826)
# Coordinates:
#   * index                    (index) int64 543kB 0 1 2 3 ... 67823 67824 67825
#     time                     (index) <U19 5MB '2019-10-29 19:00:52' ... '2019...
# Data variables: (12/26)
#     amplitude_average        (index) float64 543kB nan 60.83 ... 53.67 55.5
#     beam1_amplitude          (index) float64 543kB nan 60.5 55.5 ... 44.0 45.5
#     beam1_correlation        (index) float64 543kB nan 96.0 95.0 ... 96.0 100.0
#     beam2_amplitude          (index) float64 543kB nan 61.5 55.0 ... 52.0 54.5
#     beam3_amplitude          (index) float64 543kB nan 60.5 52.5 ... 65.0 66.5
#     beam3_correlation        (index) float64 543kB nan 79.0 86.0 ... 100.0 100.0
#     ...                       ...
#     tilt                     (index) float64 543kB nan 1.062 ... 1.058 1.058
#     u                        (index) float64 543kB nan 0.008559 ... 0.08355
# ...

# %%
#Query request for datasource adcp_sbr_site3_2019
adcp_sbr_site3_2019_query={"datasource":"adcp_sbr_site3_2019","parameters":{},"description":"ADCP Measurements (Temperature, Currents), Scott Base Redevelopment Marine Monitoring Site 3, 2019","variables":["amplitude_average","beam1_amplitude","beam1_correlation","beam2_amplitude","beam3_amplitude","beam3_correlation","correlation_average","depth","depth_bin","depth_floor","direction","heading_true","instrument_depth","latitude","longitude","magnetic_offset","magnitude","pitch","roll","temperature_of_seawater","tilt","time","u","uplooking","v","w","w2"],"functions":[],"id":"d15f0f52480f51ed9be55a7cab50b231"}
adcp_sbr_site3_2019=datamesh.query(adcp_sbr_site3_2019_query)
dsrc = datamesh.get_datasource("adcp_sbr_site3_2019")

# %% [markdown]
# ## Show the metadata - missing attributes...

# %%
dsrc
# Out:
#         ADCP Measurements (Temperature, Currents), Scott Base Redevelopment Marine Monitoring Site 3, 2019 [adcp_sbr_site3_2019]
#             Extent: (166.7309297279589, -77.85586615658141, 166.81627027204107, -77.8378998434186)
#             Timerange: 2019-11-03 00:00:00+00:00 to 2019-12-03 00:00:00+00:00
#             0 attributes
#             27 variables

# %%
print(adcp_sbr_site3_2019)
# Out:
# <xarray.Dataset> Size: 28MB
# Dimensions:                  (index: 94578)
# Coordinates:
#   * index                    (index) int64 757kB 0 1 2 3 ... 94575 94576 94577
#     time                     (index) <U19 7MB '2019-11-03 16:30:59' ... '2019...
# Data variables: (12/26)
#     amplitude_average        (index) float64 757kB nan nan nan ... 52.67 53.83
#     beam1_amplitude          (index) float64 757kB nan nan nan ... 52.5 54.0
#     beam1_correlation        (index) float64 757kB nan nan nan ... 67.0 65.0
#     beam2_amplitude          (index) float64 757kB nan nan nan ... 53.0 55.5
#     beam3_amplitude          (index) float64 757kB nan nan nan ... 52.5 52.0
#     beam3_correlation        (index) float64 757kB nan nan nan ... 92.0 92.0
#     ...                       ...
#     tilt                     (index) float64 757kB nan nan nan ... 1.462 1.373
#     u                        (index) float64 757kB nan nan ... -0.1631 -0.2461
# ...
